# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score

# %%
df=pd.read_csv('CSV-01-12/01-12/Syn.csv')
# Out:
# /home/sai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (85) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Flow ID', ' Source IP', ' Source Port',
#        ' Destination IP', ' Destination Port', ' Protocol', ' Timestamp',
#        ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',
#        'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count',
#        ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count',
#        ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio',
#        ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk',
#        ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk',
#        ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets',
#        ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes',
#        'Init_Win_bytes_forward', ' Init_Win_bytes_backward',
#        ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean',
#        ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std',
#        ' Idle Max', ' Idle Min', 'SimillarHTTP', ' Inbound', ' Label'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                                Flow ID   Source IP  \
# 0      281052  172.16.0.5-192.168.50.1-53058-53058-6  172.16.0.5
# 1      450424  172.16.0.5-192.168.50.1-32237-32237-6  172.16.0.5
# 2      182979   172.16.0.5-192.168.50.1-60495-9840-6  172.16.0.5
# 3       41540  172.16.0.5-192.168.50.1-59724-59724-6  172.16.0.5
# 4      358711  172.16.0.5-192.168.50.1-60496-32538-6  172.16.0.5
#
#     Source Port  Destination IP   Destination Port   Protocol  \
# 0         53058    192.168.50.1              53058          6
# 1         32237    192.168.50.1              32237          6
# 2         60495    192.168.50.1               9840          6
# 3         59724    192.168.50.1              59724          6
# 4         60496    192.168.50.1              32538          6
#
#                     Timestamp   Flow Duration   Total Fwd Packets  ...  \
# 0  2018-12-01 13:30:30.741451       115799309                  19  ...
# 1  2018-12-01 13:30:30.741452       113973933                  16  ...
# 2  2018-12-01 13:30:30.741501             112                   2  ...
# 3  2018-12-01 13:30:30.741563       105985004                  16  ...
# 4  2018-12-01 13:30:30.741565               1                   2  ...
#
#       Active Std   Active Max   Active Min     Idle Mean      Idle Std  \
# 0  646237.483665    1709809.0          1.0  1.426117e+07  3.220326e+06
# 1      19.595918         49.0          1.0  1.628198e+07  2.573891e+06
# 2       0.000000          0.0          0.0  0.000000e+00  0.000000e+00
# 3      17.705259         48.0          1.0  1.514071e+07  3.077366e+06
# 4       0.000000          0.0          0.0  0.000000e+00  0.000000e+00
#
#      Idle Max    Idle Min  SimillarHTTP   Inbound   Label
# 0  21714933.0  11043464.0             0         1     Syn
# 1  20019405.0  11993631.0             0         1     Syn
# 2         0.0         0.0             0         1     Syn
# 3  20954123.0  11120336.0             0         1     Syn
# 4         0.0         0.0             0         1     Syn
#
# [5 rows x 88 columns]

# %%
ack = df[' ACK Flag Count']
pd.unique(ack)
# Out:
# array([1, 0])

# %%
init = df['Init_Win_bytes_forward']
pd.unique(init)
print(max(init))
print(min(init))
# Out:
# 65535
# -1

# %%
seg = df[' min_seg_size_forward']
pd.unique(seg)
# Out:
# array([20,  0, 28, 32, 40, 24])

# %%
iat = df['Fwd IAT Total']
pd.unique(iat)
print(max(iat))
print(min(iat))
print(len(iat))
# Out:
# 119999653.0
# 0.0
# 1582681

# %%
flow = df[' Flow Duration']
pd.unique(flow)
print(max(flow))
print(min(flow))
print(len(flow))
# Out:
# 119999653
# 0
# 1582681

# %%
label = df[' Label']
pd.unique(label)
print(max(label))
print(min(label))
print(len(label))
# Out:
# Syn
# BENIGN
# 1582681

# %%
data = [df[" ACK Flag Count"], df["Init_Win_bytes_forward"],df[" min_seg_size_forward"], df["Fwd IAT Total"],df[" Flow Duration"], df[" Label"]]

# %%
headers = ["ack", "init","seg","iat","flow","label"]

# %%
df1 = pd.concat(data, axis=1, keys=headers)

# %%
df1
# Out:
#          ack  init  seg          iat       flow label
# 0          1  5840   20  115799309.0  115799309   Syn
# 1          1  5840   20  113973933.0  113973933   Syn
# 2          1  5840   20          1.0        112   Syn
# 3          1  5840   20  105985004.0  105985004   Syn
# 4          1  5840   20          1.0          1   Syn
# ...      ...   ...  ...          ...        ...   ...
# 1582676    1  5840   20          1.0          1   Syn
# 1582677    1  5840   20          1.0          1   Syn
# 1582678    1  5840   20          1.0          1   Syn
# 1582679    1  5840   20          1.0          1   Syn
# 1582680    1  5840   20         49.0         49   Syn
#
# [1582681 rows x 6 columns]

# %%
df1.to_csv("syn_attributes.csv")

# %% [markdown]
# ## Model Creation

# %%
df1=pd.read_csv('syn_attributes.csv')

# %%
from pycaret.classification import *
from sklearn.preprocessing import LabelEncoder

# %%
# label encoding for Y values
Encoder = LabelEncoder()
le = Encoder.fit(df1["label"])
df1["label"] = le.transform(df1["label"])

# %%
pd.unique(df1['label'])
# 1 = Syn
# 0 = Benign
# Out:
# array([1, 0])

# %%
df1
# Out:
#          Unnamed: 0  ack  init  seg          iat       flow  label
# 0                 0    1  5840   20  115799309.0  115799309      1
# 1                 1    1  5840   20  113973933.0  113973933      1
# 2                 2    1  5840   20          1.0        112      1
# 3                 3    1  5840   20  105985004.0  105985004      1
# 4                 4    1  5840   20          1.0          1      1
# ...             ...  ...   ...  ...          ...        ...    ...
# 1582676     1582676    1  5840   20          1.0          1      1
# 1582677     1582677    1  5840   20          1.0          1      1
# 1582678     1582678    1  5840   20          1.0          1      1
# 1582679     1582679    1  5840   20          1.0          1      1
# 1582680     1582680    1  5840   20         49.0         49      1
#
# [1582681 rows x 7 columns]

# %%
# sample 10000 points from majority class to create new dataset
df_maj = df1[df1['label']==1]
df_min = df1[df1['label']==0]
df_maj = df_maj.sample(n=10000)
df_maj = pd.concat([df_maj,df_min], axis=0)

# %%
len(df_maj)
# Out:
# 10392

# %%
X = df_maj.drop('label',axis=1)
y = df_maj['label']

# %%
X
# Out:
#          Unnamed: 0  ack  init  seg       iat    flow
# 1393327     1393327    1  5840   20      49.0      49
# 44728         44728    1  5840   20       1.0       1
# 1324143     1324143    1  5840   20       1.0       1
# 490627       490627    1  5840   20       1.0       1
# 396616       396616    1  5840   20       1.0       1
# ...             ...  ...   ...  ...       ...     ...
# 1479185     1479185    0  4253   20  499664.0  499664
# 1482435     1482435    0  4253   20       0.0     217
# 1482436     1482436    0  4253   20       0.0     194
# 1502348     1502348    0    -1   20       2.0   20808
# 1502473     1502473    0    -1   20       2.0   45944
#
# [10392 rows x 6 columns]

# %%
X['init'].value_counts()

# %%
# train and test split from newly created dataset 
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32, shuffle=True)

# %%
y_test.value_counts()
# Out:
# 1    1985
# 0      94
# Name: label, dtype: int64

# %%
# perform smote for the dataset to solve imbalance
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
x_train, y_train = oversample.fit_resample(x_train, y_train)

# %%
y_train.value_counts()
# Out:
# 0    8015
# 1    8015
# Name: label, dtype: int64

# %%
x_train
# Out:
#        Unnamed: 0  ack   init  seg           iat      flow
# 0          152094    1   5840   20  1.000000e+00         1
# 1          909726    1   8192   20  5.908991e+07  59089908
# 2         1480167    1   5840   20  4.900000e+01       115
# 3         1298896    1   5840   20  1.000000e+00        88
# 4          867320    1   5840   20  1.000000e+00        47
# ...           ...  ...    ...  ...           ...       ...
# 16025     1103967    0    257   20  5.813376e+07  58133760
# 16026      418961    0   1868   20  2.505627e-02       555
# 16027      329474    0     -1   20  2.000000e+00     46083
# 16028      664248    1   8192   20  1.478617e+06   1559481
# 16029      317176    0  16236   20  3.406953e+02       340
#
# [16030 rows x 6 columns]

# %%
# concatenate dataset for passing to pycaret
train_dataset = pd.concat([x_train,y_train],axis=1)
test_dataset = pd.concat([x_test,y_test],axis=1)

# %%
# train_dataset.drop(['Unnamed: 0'],axis=1,inplace=True)
test_dataset.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
train_dataset
# Out:
#        ack   init  seg           iat      flow  label
# 0        1   5840   20  1.000000e+00         1      1
# 1        1   8192   20  5.908991e+07  59089908      0
# 2        1   5840   20  4.900000e+01       115      1
# 3        1   5840   20  1.000000e+00        88      1
# 4        1   5840   20  1.000000e+00        47      1
# ...    ...    ...  ...           ...       ...    ...
# 16025    0    257   20  5.813376e+07  58133760      0
# 16026    0   1868   20  2.505627e-02       555      0
# 16027    0     -1   20  2.000000e+00     46083      0
# 16028    1   8192   20  1.478617e+06   1559481      0
# 16029    0  16236   20  3.406953e+02       340      0
#
# [16030 rows x 6 columns]

# %%
test_dataset
# Out:
#          ack  init  seg          iat       flow  label
# 1051676    1  5840   20          1.0          1      1
# 67406      1  5840   20          1.0          1      1
# 981117     1  5840   20          1.0          1      1
# 4057       1  5840   20  109278157.0  109278157      1
# 1179226    1  5840   20          1.0          1      1
# ...      ...   ...  ...          ...        ...    ...
# 228768     1  5840   20          1.0          1      1
# 1055197    1  5840   20          1.0          1      1
# 688057     1  5840   20          1.0          1      1
# 1487975    1  5840   20          1.0          1      1
# 865982     1  5840   20          1.0          1      1
#
# [2079 rows x 6 columns]

# %%
len(train_dataset['init'].value_counts())
# Out:
# 1845

# %%
# pycaret init
exp = setup(data = train_dataset, target='label', train_size = 1.0, preprocess = True, test_data = test_dataset, session_id=1, use_gpu=True)
# Out:
# <style  type="text/css" >
# #T_e5853_row0_col1,#T_e5853_row18_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_e5853_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e5853_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e5853_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e5853_row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e5853_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_e5853_row1_col1" class="data row1 col1" >label</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e5853_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_e5853_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e5853_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_e5853_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e5853_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_e5853_row4_col1" class="data row4 col1" >(16030, 6)</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e5853_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_e5853_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e5853_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_e5853_row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e5853_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_e5853_row7_col1" class="data row7 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e5853_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_e5853_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e5853_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_e5853_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e5853_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_e5853_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_e5853_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_e5853_row11_col1" class="data row11 col1" >(16030, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_e5853_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_e5853_row12_col1" class="data row12 col1" >(2079, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_e5853_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_e5853_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_e5853_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_e5853_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_e5853_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_e5853_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_e5853_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_e5853_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_e5853_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_e5853_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_e5853_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_e5853_row18_col1" class="data row18 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_e5853_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_e5853_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_e5853_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_e5853_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_e5853_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_e5853_row21_col1" class="data row21 col1" >e079</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_e5853_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_e5853_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_e5853_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_e5853_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e5853_level0_row24" class="row_heading leve

# %%
xgb_model = create_model('xgboost')
# Out:
# <style  type="text/css" >
# #T_ecb3d_row10_col0,#T_ecb3d_row10_col1,#T_ecb3d_row10_col2,#T_ecb3d_row10_col3,#T_ecb3d_row10_col4,#T_ecb3d_row10_col5,#T_ecb3d_row10_col6{
#             background:  yellow;
#         }</style><table id="T_ecb3d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ecb3d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ecb3d_row0_col0" class="data row0 col0" >0.9981</td>
#                         <td id="T_ecb3d_row0_col1" class="data row0 col1" >1.0000</td>
#                         <td id="T_ecb3d_row0_col2" class="data row0 col2" >1.0000</td>
#                         <td id="T_ecb3d_row0_col3" class="data row0 col3" >0.9963</td>
#                         <td id="T_ecb3d_row0_col4" class="data row0 col4" >0.9981</td>
#                         <td id="T_ecb3d_row0_col5" class="data row0 col5" >0.9963</td>
#                         <td id="T_ecb3d_row0_col6" class="data row0 col6" >0.9963</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ecb3d_row1_col0" class="data row1 col0" >1.0000</td>
#                         <td id="T_ecb3d_row1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_ecb3d_row1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_ecb3d_row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_ecb3d_row1_col4" class="data row1 col4" >1.0000</td>
#                         <td id="T_ecb3d_row1_col5" class="data row1 col5" >1.0000</td>
#                         <td id="T_ecb3d_row1_col6" class="data row1 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ecb3d_row2_col0" class="data row2 col0" >0.9994</td>
#                         <td id="T_ecb3d_row2_col1" class="data row2 col1" >1.0000</td>
#                         <td id="T_ecb3d_row2_col2" class="data row2 col2" >1.0000</td>
#                         <td id="T_ecb3d_row2_col3" class="data row2 col3" >0.9988</td>
#                         <td id="T_ecb3d_row2_col4" class="data row2 col4" >0.9994</td>
#                         <td id="T_ecb3d_row2_col5" class="data row2 col5" >0.9988</td>
#                         <td id="T_ecb3d_row2_col6" class="data row2 col6" >0.9988</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ecb3d_row3_col0" class="data row3 col0" >1.0000</td>
#                         <td id="T_ecb3d_row3_col1" class="data row3 col1" >1.0000</td>
#                         <td id="T_ecb3d_row3_col2" class="data row3 col2" >1.0000</td>
#                         <td id="T_ecb3d_row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_ecb3d_row3_col4" class="data row3 col4" >1.0000</td>
#                         <td id="T_ecb3d_row3_col5" class="data row3 col5" >1.0000</td>
#                         <td id="T_ecb3d_row3_col6" class="data row3 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ecb3d_row4_col0" class="data row4 col0" >1.0000</td>
#                         <td id="T_ecb3d_row4_col1" class="data row4 col1" >1.0000</td>
#                         <td id="T_ecb3d_row4_col2" class="data row4 col2" >1.0000</td>
#                         <td id="T_ecb3d_row4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_ecb3d_row4_col4" class="data row4 col4" >1.0000</td>
#                         <td id="T_ecb3d_row4_col5" class="data row4 col5" >1.0000</td>
#                         <td id="T_ecb3d_row4_col6" class="data row4 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ecb3d_row5_col0" class="data row5 col0" >0.9988</td>
#                         <td id="T_ecb3d_row5_col1" class="data row5 col1" >0.9998</td>
#                         <td id="T_ecb3d_row5_col2" class="data row5 col2" >0.9975</td>
#                         <td id="T_ecb3d_row5_col3" class="data row5 col3" >1.0000</td>
#                         <td id="T_ecb3d_row5_col4" class="data row5 col4" >0.9988</td>
#                         <td id="T_ecb3d_row5_col5" class="data row5 col5" >0.9975</td>
#                         <td id="T_ecb3d_row5_col6" class="data row5 col6" >0.9975</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ecb3d_row6_col0" class="data row6 col0" >0.9994</td>
#                         <td id="T_ecb3d_row6_col1" class="data row6 col1" >1.0000</td>
#                         <td id="T_ecb3d_row6_col2" class="data row6 col2" >0.9988</td>
#                         <td id="T_ecb3d_row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_ecb3d_row6_col4" class="data row6 col4" >0.9994</td>
#                         <td id="T_ecb3d_row6_col5" class="data row6 col5" >0.9988</td>
#                         <td id="T_ecb3d_row6_col6" class="data row6 col6" >0.9988</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ecb3d_row7_col0" class="data row7 col0" >1.0000</td>
#                         <td id="T_ecb3d_row7_col1" class="data row7 col1" >1.0000</td>
#                         <td id="T_ecb3d_row7_col2" class="data row7 col2" >1.0000</td>
#                         <td id="T_ecb3d_row7_col3" class="data row7 col3" >1.0000</td>
#                         <td id="T_ecb3d_row7_col4" class="data row7 col4" >1.0000</td>
#                         <td id="T_ecb3d_row7_col5" class="data row7 col5" >1.0000</td>
#                         <td id="T_ecb3d_row7_col6" class="data row7 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ecb3d_row8_col0" class="data row8 col0" >1.0000</td>
#                         <td id="T_ecb3d_row8_col1" class="data row8 col1" >1.0000</td>
#                         <td id="T_ecb3d_row8_col2" class="data row8 col2" >1.0000</td>
#                         <td id="T_ecb3d_row8_col3" class="data row8 col3" >1.0000</td>
#                         <td id="T_ecb3d_row8_col4" class="data row8 col4" >1.0000</td>
#                         <td id="T_ecb3d_row8_col5" class="data row8 col5" >1.0000</td>
#                         <td id="T_ecb3d_row8_col6" class="data row8 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_ecb3d_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ecb3d_row9_col0" class="data row9 col0" >0.9994</td>
#                         <td id="T_ecb3d_row9_col1" class="data row9 col1" >1.0000</td>
#                         <td id="T_ecb3d_row9_col2" class="data row9 col2" >0.9988</td>
#                         <td id="T_ecb3d_row9_col3" class="data row9 col3" >1.0000</td>
#                         <td id="T_ecb3d_row9_col4" class="data row9 col4" >0.9994</td>
#                         <td id="T_ecb3d_row9_col5" class="data row9 col5" >0.9988</td>
#                         <td id=

# %%
tuned_xgb = tune_model(xgb_model, optimize = 'AUC')
# Out:
# <style  type="text/css" >
# #T_22e7a_row10_col0,#T_22e7a_row10_col1,#T_22e7a_row10_col2,#T_22e7a_row10_col3,#T_22e7a_row10_col4,#T_22e7a_row10_col5,#T_22e7a_row10_col6{
#             background:  yellow;
#         }</style><table id="T_22e7a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22e7a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_22e7a_row0_col0" class="data row0 col0" >0.9981</td>
#                         <td id="T_22e7a_row0_col1" class="data row0 col1" >1.0000</td>
#                         <td id="T_22e7a_row0_col2" class="data row0 col2" >1.0000</td>
#                         <td id="T_22e7a_row0_col3" class="data row0 col3" >0.9963</td>
#                         <td id="T_22e7a_row0_col4" class="data row0 col4" >0.9981</td>
#                         <td id="T_22e7a_row0_col5" class="data row0 col5" >0.9963</td>
#                         <td id="T_22e7a_row0_col6" class="data row0 col6" >0.9963</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_22e7a_row1_col0" class="data row1 col0" >1.0000</td>
#                         <td id="T_22e7a_row1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_22e7a_row1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_22e7a_row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_22e7a_row1_col4" class="data row1 col4" >1.0000</td>
#                         <td id="T_22e7a_row1_col5" class="data row1 col5" >1.0000</td>
#                         <td id="T_22e7a_row1_col6" class="data row1 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_22e7a_row2_col0" class="data row2 col0" >0.9994</td>
#                         <td id="T_22e7a_row2_col1" class="data row2 col1" >1.0000</td>
#                         <td id="T_22e7a_row2_col2" class="data row2 col2" >1.0000</td>
#                         <td id="T_22e7a_row2_col3" class="data row2 col3" >0.9988</td>
#                         <td id="T_22e7a_row2_col4" class="data row2 col4" >0.9994</td>
#                         <td id="T_22e7a_row2_col5" class="data row2 col5" >0.9988</td>
#                         <td id="T_22e7a_row2_col6" class="data row2 col6" >0.9988</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_22e7a_row3_col0" class="data row3 col0" >1.0000</td>
#                         <td id="T_22e7a_row3_col1" class="data row3 col1" >1.0000</td>
#                         <td id="T_22e7a_row3_col2" class="data row3 col2" >1.0000</td>
#                         <td id="T_22e7a_row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_22e7a_row3_col4" class="data row3 col4" >1.0000</td>
#                         <td id="T_22e7a_row3_col5" class="data row3 col5" >1.0000</td>
#                         <td id="T_22e7a_row3_col6" class="data row3 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_22e7a_row4_col0" class="data row4 col0" >0.9994</td>
#                         <td id="T_22e7a_row4_col1" class="data row4 col1" >1.0000</td>
#                         <td id="T_22e7a_row4_col2" class="data row4 col2" >1.0000</td>
#                         <td id="T_22e7a_row4_col3" class="data row4 col3" >0.9988</td>
#                         <td id="T_22e7a_row4_col4" class="data row4 col4" >0.9994</td>
#                         <td id="T_22e7a_row4_col5" class="data row4 col5" >0.9988</td>
#                         <td id="T_22e7a_row4_col6" class="data row4 col6" >0.9988</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_22e7a_row5_col0" class="data row5 col0" >0.9994</td>
#                         <td id="T_22e7a_row5_col1" class="data row5 col1" >1.0000</td>
#                         <td id="T_22e7a_row5_col2" class="data row5 col2" >0.9988</td>
#                         <td id="T_22e7a_row5_col3" class="data row5 col3" >1.0000</td>
#                         <td id="T_22e7a_row5_col4" class="data row5 col4" >0.9994</td>
#                         <td id="T_22e7a_row5_col5" class="data row5 col5" >0.9988</td>
#                         <td id="T_22e7a_row5_col6" class="data row5 col6" >0.9988</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_22e7a_row6_col0" class="data row6 col0" >0.9994</td>
#                         <td id="T_22e7a_row6_col1" class="data row6 col1" >1.0000</td>
#                         <td id="T_22e7a_row6_col2" class="data row6 col2" >0.9988</td>
#                         <td id="T_22e7a_row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_22e7a_row6_col4" class="data row6 col4" >0.9994</td>
#                         <td id="T_22e7a_row6_col5" class="data row6 col5" >0.9988</td>
#                         <td id="T_22e7a_row6_col6" class="data row6 col6" >0.9988</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_22e7a_row7_col0" class="data row7 col0" >1.0000</td>
#                         <td id="T_22e7a_row7_col1" class="data row7 col1" >1.0000</td>
#                         <td id="T_22e7a_row7_col2" class="data row7 col2" >1.0000</td>
#                         <td id="T_22e7a_row7_col3" class="data row7 col3" >1.0000</td>
#                         <td id="T_22e7a_row7_col4" class="data row7 col4" >1.0000</td>
#                         <td id="T_22e7a_row7_col5" class="data row7 col5" >1.0000</td>
#                         <td id="T_22e7a_row7_col6" class="data row7 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_22e7a_row8_col0" class="data row8 col0" >1.0000</td>
#                         <td id="T_22e7a_row8_col1" class="data row8 col1" >1.0000</td>
#                         <td id="T_22e7a_row8_col2" class="data row8 col2" >1.0000</td>
#                         <td id="T_22e7a_row8_col3" class="data row8 col3" >1.0000</td>
#                         <td id="T_22e7a_row8_col4" class="data row8 col4" >1.0000</td>
#                         <td id="T_22e7a_row8_col5" class="data row8 col5" >1.0000</td>
#                         <td id="T_22e7a_row8_col6" class="data row8 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_22e7a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_22e7a_row9_col0" class="data row9 col0" >1.0000</td>
#                         <td id="T_22e7a_row9_col1" class="data row9 col1" >1.0000</td>
#                         <td id="T_22e7a_row9_col2" class="data row9 col2" >1.0000</td>
#                         <td id="T_22e7a_row9_col3" class="data row9 col3" >1.0000</td>
#                         <td id="T_22e7a_row9_col4" class="data row9 col4" >1.0000</td>
#                         <td id="T_22e7a_row9_col5" class="data row9 col5" >1.0000</td>
#                         <td id=

# %% [markdown]
# ## Manual training

# %%
x_test.drop(['Unnamed: 0'],axis=1,inplace=True)
x_train.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
x_test
# Out:
#          ack  init  seg          iat       flow
# 1051676    1  5840   20          1.0          1
# 67406      1  5840   20          1.0          1
# 981117     1  5840   20          1.0          1
# 4057       1  5840   20  109278157.0  109278157
# 1179226    1  5840   20          1.0          1
# ...      ...   ...  ...          ...        ...
# 228768     1  5840   20          1.0          1
# 1055197    1  5840   20          1.0          1
# 688057     1  5840   20          1.0          1
# 1487975    1  5840   20          1.0          1
# 865982     1  5840   20          1.0          1
#
# [2079 rows x 5 columns]

# %%
x_train
# Out:
#        ack   init  seg           iat      flow
# 0        1   5840   20  1.000000e+00         1
# 1        1   8192   20  5.908991e+07  59089908
# 2        1   5840   20  4.900000e+01       115
# 3        1   5840   20  1.000000e+00        88
# 4        1   5840   20  1.000000e+00        47
# ...    ...    ...  ...           ...       ...
# 16025    0    257   20  5.813376e+07  58133760
# 16026    0   1868   20  2.505627e-02       555
# 16027    0     -1   20  2.000000e+00     46083
# 16028    1   8192   20  1.478617e+06   1559481
# 16029    0  16236   20  3.406953e+02       340
#
# [16030 rows x 5 columns]

# %% [markdown]
# ### Training Different Models

# %%
xgb = XGBClassifier(scale_pos_weight=1)
xgb_clf = xgb.fit(x_train,y_train)
predictions_xgb = xgb_clf.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        94
#            1       1.00      1.00      1.00      1985
#
#     accuracy                           1.00      2079
#    macro avg       0.99      1.00      1.00      2079
# weighted avg       1.00      1.00      1.00      2079

# %%
print("xgb Score -> ",accuracy_score(predictions_xgb, y_test)*100)
print("xgb roc_auc Score -> ",roc_auc_score(y_test,predictions_xgb))
print("f1 score ->", f1_score(y_test,predictions_xgb))
# Out:
# xgb Score ->  99.95189995189995
# xgb roc_auc Score ->  0.9997481108312343
# f1 score -> 0.999748047367095
